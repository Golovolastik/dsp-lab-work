# %% [markdown]
# # Individual Practice Task

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Harmonic Signal Function

# %%
def generate_harmonic_signal(A, phi, f, N, n):
    '''
    A - amplitude
    phi - phase
    f - frequency
    N - number of samples
    n - sample index
    '''
    return A * np.sin(2 * np.pi * f * n / N + phi)

# %% [markdown]
# ## Polyharmonic Signal Function

# %%
def generate_polyharmonic_signal(A, phi, f, N, n):
    '''
    A - amplitude
    phi - phase
    f - frequency
    N - number of samples
    n - sample index
    k - number of harmonics
    '''
    for k in range(k):
        signal += generate_harmonic_signal(A[k], phi[k], f[k], N, n)
    return signal

# %% [markdown]
# ## Auxiliary Functions

# %%
def draw_signal(signal, title):
    plt.figure(figsize=(10, 6))
    plt.plot(signal)
    plt.title(title)
    plt.xlabel('Sample index')
    plt.ylabel('Amplitude')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Task 2(A) Completion

# %%
def task_2A():
    # Option 1 conditions
    A = 10
    f = 2
    N = 2048
    n = np.arange(N)
    phi_options = [0, np.pi/6, np.pi/4, np.pi/2, np.pi]

    for phi in phi_options:
        signal = generate_harmonic_signal(A, phi, f, N, n)
        draw_signal(signal, f"Option 1: phi = {phi}")

# %% [markdown]
# ## Task 2(B) Completion

# %%
def task_2C():
    # Option 1 conditions
    A_options = [2, 3, 6, 5, 1]
    f = 1
    N = 2048
    n = np.arange(N)
    phi = np.pi/2

    for A in A_options:
        signal = generate_harmonic_signal(A, phi, f, N, n)
        draw_signal(signal, f"Option 1: phi = {phi}")

# %% [markdown]
# ## Task 2(Б) Completion

# %%
def task_2B():
    # Option 1 conditions
    A = 3
    f_options = [5, 4, 2, 6, 3]
    N = 2048
    n = np.arange(N)
    phi = np.pi/2

    for f in f_options:
        signal = generate_harmonic_signal(A, phi, f, N, n)
        draw_signal(signal, f"Option 1: f = {f}")

# %% [markdown]
# ## Execute Tasks

# %% [markdown]
# ### Task 2(A)

# %%
task_2A()

# %% [markdown]
# ### Task 2(Б)

# %%
task_2B()

# %% [markdown]
# ### Task 2(В)

# %%
task_2C()
